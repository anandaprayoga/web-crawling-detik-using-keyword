# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

from tqdm import tqdm

# %%
# dapatkan url berita
def getUrlFromPage(url, headers, keyword):
    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        titles = soup.find_all("h3", class_="media__title")

        data = [
            {
                "title": a.get_text(strip=True),
                "link": a["href"],
                "keyword": keyword
            }
            for a in soup.select("h3.media__title a.media__link")
        ]

        return data

    except Exception as e:
        print(f"Error on page {url}: {e}")
        return None

def main():
    try:
        headers = {
            "User-Agent": "Mozilla/5.0"
        }

        next_page = True
        page = 1
        all_url = []

        # ubah
        limit_page = 200
        keyword = "tbc"
        start_page_url = f"https://www.detik.com/search/searchall?query={keyword}&result_type=relevansi&page="
        output_path = "/content/data"
        filename = f"list_url_{keyword}.csv"

        while next_page:
            current_page_url = start_page_url+str(page)
            response = requests.get(current_page_url, headers=headers)

            print(f"page={page}, url='{current_page_url}', {response}")

            url = getUrlFromPage(current_page_url, headers, keyword)

            all_url.extend(url)

            if page == limit_page:
                next_page = False

            page += 1

        os.makedirs(output_path, exist_ok=True)

        df = pd.DataFrame(all_url)
        df.to_csv(f"{output_path}/{filename}", index=False)

    except Exception as e:
        print(f"Error: {e}")
        return None

# main()

# %%
# merge
df_diabetes = pd.read_csv("/content/data/list_url_diabetes.csv")
df_tbc = pd.read_csv("/content/data/list_url_tbc.csv")

df = pd.concat([df_diabetes, df_tbc], ignore_index=True)
df.to_csv("/content/data/list_url.csv")

# %%
# seleksi non artikel
df = pd.read_csv("/content/data/list_url.csv")

def is_article(url):
    return ("berita" in url
            and "detiktv" not in url
            and "video" not in url
            and "20.detik.com" not in url)

df = df[df["link"].apply(is_article)]
df.to_csv("/content/data/list_url_selected.csv")

# %%
# df.rename(columns={'label': 'keyword'}, inplace=True)
df
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Andre Rosiade Bantu Istri Pemulung Pengidap Di...
# 1              1  Pasien Diabetes Tak Lagi Perlu Minum Obat Seum...
# 8              8  18 April Hari Diabetes Nasional dan Kenali Car...
# 17            17  Terungkap Pemicu Terbesar Gagal Ginjal Makin M...
# 24            24  Jebakan 'Hidden Sugar' di Minuman Manis yang B...
# ...          ...                                                ...
# 3332        3332  Kasus TB di Ciamis, Hampir 1 Pasien Meninggal ...
# 3333        3333  Peringatan BP2MI soal Risiko Tinggi Jadi Peker...
# 3334        3334  Jepang yang Bakal Wajibkan WNI Tes TBC Mulai 2...
# 3335        3335  Alam Bintaro Tewas di Rumah Diduga karena TBC,...
# 3336        3336  Dinkes Catat 1.002 Kasus TBC Terjadi di Kota B...
#
#                                                    link   keyword
# 0     https://news.detik.com/berita/d-8452634/andre-...  diabetes
# 1     https://health.detik.com/berita-detikhealth/d-...  diabetes
# 8     https://www.detik.com/bali/berita/d-8450035/18...  diabetes
# 17    https://health.detik.com/berita-detikhealth/d-...  diabetes
# 24    https://health.detik.com/berita-detikhealth/d-...  diabetes
# ...                                                 ...       ...
# 3332  https://www.detik.com/jabar/berita/d-5998473/k...       tbc
# 3333  https://www.detik.com/sulsel/berita/d-7162859/...       tbc
# 3334  https://health.detik.com/berita-detikhealth/d-...       tbc
# 3335  https://www.detik.com/sumbagsel/berita/d-71219...       tbc
# 3336  https://news.detik.com/berita/d-7221558/dinkes...       tbc
#
# [2205 rows x 4 columns]

# %%
df = pd.read_csv("/content/data/list_url_selected.csv")
df = df.rename(columns={'label': 'keyword'})

# %%
headers = {"User-Agent": "Mozilla/5.0"}

def get_content(url):
    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            return None

        soup = BeautifulSoup(response.text, "html.parser")

        container = soup.select_one("div.detail__body-text.itp_bodycontent")

        if not container:
            container = soup.select_one("div.detail__body-text")

        if not container:
            container = soup.select_one("div.itp_bodycontent")

        if not container:
            print("Failed selector:", url)
            return None

        paragraphs = container.find_all("p")

        texts = []
        for p in paragraphs:
            txt = p.get_text(strip=True)

            if not txt:
                continue
            if "ADVERTISEMENT" in txt.upper():
                continue

            texts.append(txt)

        return " ".join(texts) if texts else None

    except:
        return None

tqdm.pandas()

content_series = df["link"].progress_apply(get_content)
# Out:
# 100%|██████████| 2205/2205 [58:31<00:00,  1.59s/it]

# %%
df['content'] = content_series

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                8           8
# 3               17          17
# 4               24          24
# ...            ...         ...
# 2200          3332        3332
# 2201          3333        3333
# 2202          3334        3334
# 2203          3335        3335
# 2204          3336        3336
#
#                                                   title  \
# 0     Andre Rosiade Bantu Istri Pemulung Pengidap Di...
# 1     Pasien Diabetes Tak Lagi Perlu Minum Obat Seum...
# 2     18 April Hari Diabetes Nasional dan Kenali Car...
# 3     Terungkap Pemicu Terbesar Gagal Ginjal Makin M...
# 4     Jebakan 'Hidden Sugar' di Minuman Manis yang B...
# ...                                                 ...
# 2200  Kasus TB di Ciamis, Hampir 1 Pasien Meninggal ...
# 2201  Peringatan BP2MI soal Risiko Tinggi Jadi Peker...
# 2202  Jepang yang Bakal Wajibkan WNI Tes TBC Mulai 2...
# 2203  Alam Bintaro Tewas di Rumah Diduga karena TBC,...
# 2204  Dinkes Catat 1.002 Kasus TBC Terjadi di Kota B...
#
#                                                    link   keyword  \
# 0     https://news.detik.com/berita/d-8452634/andre-...  diabetes
# 1     https://health.detik.com/berita-detikhealth/d-...  diabetes
# 2     https://www.detik.com/bali/berita/d-8450035/18...  diabetes
# 3     https://health.detik.com/berita-detikhealth/d-...  diabetes
# 4     https://health.detik.com/berita-detikhealth/d-...  diabetes
# ...                                                 ...       ...
# 2200  https://www.detik.com/jabar/berita/d-5998473/k...       tbc
# 2201  https://www.detik.com/sulsel/berita/d-7162859/...       tbc
# 2202  https://health.detik.com/berita-detikhealth/d-...       tbc
# 2203  https://www.detik.com/sumbagsel/berita/d-71219...       tbc
# 2204  https://news.detik.com/berita/d-7221558/dinkes...       tbc
#
#                                                 content
# 0     Wakil Ketua Komisi VI DPR RI dari Fraksi Gerin...
# 1     Ketua Umum Perkumpulan Endokrinologi Indonesia...
# 2     Setiap tahun, tanggal 18 April selalu dipering...
# 3     Kementerian Kesehatan RI mengungkap tren mengk...
# 4     Kabar baik bagi kesehatan publik di Indonesia....
# ...                                                 ...
# 2200  Kasus tuberkulosis (TB) di Kabupaten Ciamis ma...
# 2201  Kepala Badan Perlindungan Pekerja Migran (BP2M...
# 2202  Kementerian Kesehatan RI (Kemenkes) menanggapi...
# 2203  Misteri kematian pria di Lubuklinggau, Sumater...
# 2204  Dinas Kesehatan (Dinkes) mencatat sebanyak 1.0...
#
# [2205 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1     0
# Unnamed: 0       0
# title            0
# link             0
# keyword          0
# content         21
# dtype: int64

# %%
df.to_csv('/content/data/dataset.csv')
